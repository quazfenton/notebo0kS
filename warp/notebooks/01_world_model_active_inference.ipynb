# %% [markdown]
# # 01 — World Model with Active Inference (Smoke)
# Run a short training and visualize logs.

# %%
# !pip install -e .  # if needed
# !python scripts/train_worldmodel.py tiny=true optim.steps=300 logging.every=50
