# %% [markdown]
# # 03 — Slot-Program on Synthetic CLEVR (Smoke)
# Generates a tiny dataset and runs a short training.

# %%
# !python scripts/synth_generate_clevr.py --n 256 --out data/clevr_tiny --img 64 --min 2 --max 5 --seed 0
# !python scripts/train_slotprog.py tiny=true optim.steps=300 logging.every=50
